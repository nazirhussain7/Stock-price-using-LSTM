# %%
# Importing required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
google_stock_data = pd.read_csv('GOOG (1).csv')
google_stock_data.head()
# Out:
#   symbol                       date   close    high       low    open  \
# 0   GOOG  2016-06-14 00:00:00+00:00  718.27  722.47  713.1200  716.48
# 1   GOOG  2016-06-15 00:00:00+00:00  718.92  722.98  717.3100  719.00
# 2   GOOG  2016-06-16 00:00:00+00:00  710.36  716.65  703.2600  714.91
# 3   GOOG  2016-06-17 00:00:00+00:00  691.72  708.82  688.4515  708.65
# 4   GOOG  2016-06-20 00:00:00+00:00  693.71  702.48  693.4100  698.77
#
#     volume  adjClose  adjHigh    adjLow  adjOpen  adjVolume  divCash  \
# 0  1306065    718.27   722.47  713.1200   716.48    1306065      0.0
# 1  1214517    718.92   722.98  717.3100   719.00    1214517      0.0
# 2  1982471    710.36   716.65  703.2600   714.91    1982471      0.0
# 3  3402357    691.72   708.82  688.4515   708.65    3402357      0.0
# 4  2082538    693.71   702.48  693.4100   698.77    2082538      0.0
#
#    splitFactor
# 0          1.0
# 1          1.0
# 2          1.0
# 3          1.0
# 4          1.0

# %%
google_stock_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   symbol       1258 non-null   object
#  1   date         1258 non-null   object
#  2   close        1258 non-null   float64
#  3   high         1258 non-null   float64
#  4   low          1258 non-null   float64
#  5   open         1258 non-null   float64
#  6   volume       1258 non-null   int64
#  7   adjClose     1258 non-null   float64
#  8   adjHigh      1258 non-null   float64
#  9   adjLow       1258 non-null   float64
#  10  adjOpen      1258 non-null   float64
#  11  adjVolume    1258 non-null   int64
#  12  divCash      1258 non-null   float64
#  13  splitFactor  1258 non-null   float64
# dtypes: float64(10), int64(2), object(2)
# memory usage: 137.7+ KB

# %%
google_stock_data = google_stock_data[['date','open','close']] # Extracting required columns
google_stock_data['date'] = pd.to_datetime(google_stock_data['date'].apply(lambda x: x.split()[0])) # Selecting only date
google_stock_data.set_index('date',drop=True,inplace=True) # Setting date column as index
google_stock_data.head()
# Out:
#               open   close
# date
# 2016-06-14  716.48  718.27
# 2016-06-15  719.00  718.92
# 2016-06-16  714.91  710.36
# 2016-06-17  708.65  691.72
# 2016-06-20  698.77  693.71

# %%
fg, ax =plt.subplots(1,2,figsize=(20,7))
ax[0].plot(google_stock_data['open'],label='Open',color='green')
ax[0].set_xlabel('Date',size=15)
ax[0].set_ylabel('Price',size=15)
ax[0].legend()

ax[1].plot(google_stock_data['close'],label='Close',color='red')
ax[1].set_xlabel('Date',size=15)
ax[1].set_ylabel('Price',size=15)
ax[1].legend()

fg.show()
# Out:
# C:\Users\NAZIRH~1\AppData\Local\Temp/ipykernel_2928/52026741.py:12: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fg.show()

# %%
from sklearn.preprocessing import MinMaxScaler
MMS = MinMaxScaler()
google_stock_data[google_stock_data.columns] = MMS.fit_transform(google_stock_data)

# %%
google_stock_data.shape
# Out:
# (1258, 2)

# %%
training_size = round(len(google_stock_data) * 0.80) # Selecting 80 % for training and 20 % for testing
training_size
# Out:
# 1006

# %%
train_data = google_stock_data[:training_size]
test_data  = google_stock_data[training_size:]

train_data.shape, test_data.shape
# Out:
# ((1006, 2), (252, 2))

# %%
# Function to create sequence of data for training and testing

def create_sequence(dataset):
  sequences = []
  labels = []

  start_idx = 0

  for stop_idx in range(50,len(dataset)): # Selecting 50 rows at a time
    sequences.append(dataset.iloc[start_idx:stop_idx])
    labels.append(dataset.iloc[stop_idx])
    start_idx += 1
  return (np.array(sequences),np.array(labels))

# %%
train_seq, train_label = create_sequence(train_data)
test_seq, test_label = create_sequence(test_data)

# %%
train_seq.shape, train_label.shape, test_seq.shape, test_label.shape
# Out:
# ((956, 50, 2), (956, 2), (202, 50, 2), (202, 2))

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Bidirectional

# %%
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape = (train_seq.shape[1], train_seq.shape[2])))

model.add(Dropout(0.1)) 
model.add(LSTM(units=50))

model.add(Dense(2))

model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_absolute_error'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 50, 50)            10600
#
#  dropout (Dropout)           (None, 50, 50)            0
#
#  lstm_1 (LSTM)               (None, 50)                20200
#
#  dense (Dense)               (None, 2)                 102
#
# =================================================================
# Total params: 30,902
# Trainable params: 30,902
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(train_seq, train_label, epochs=80,validation_data=(test_seq, test_label), verbose=1)
# Out:
# Epoch 1/80
# 30/30 [==============================] - 6s 56ms/step - loss: 0.0064 - mean_absolute_error: 0.0566 - val_loss: 0.0182 - val_mean_absolute_error: 0.1128
# Epoch 2/80
# 30/30 [==============================] - 1s 27ms/step - loss: 7.8468e-04 - mean_absolute_error: 0.0218 - val_loss: 0.0096 - val_mean_absolute_error: 0.0820
# Epoch 3/80
# 30/30 [==============================] - 1s 27ms/step - loss: 5.7439e-04 - mean_absolute_error: 0.0170 - val_loss: 0.0101 - val_mean_absolute_error: 0.0840
# Epoch 4/80
# 30/30 [==============================] - 1s 27ms/step - loss: 5.4107e-04 - mean_absolute_error: 0.0167 - val_loss: 0.0059 - val_mean_absolute_error: 0.0617
# Epoch 5/80
# 30/30 [==============================] - 1s 26ms/step - loss: 4.9989e-04 - mean_absolute_error: 0.0160 - val_loss: 0.0077 - val_mean_absolute_error: 0.0736
# Epoch 6/80
# 30/30 [==============================] - 1s 26ms/step - loss: 5.1075e-04 - mean_absolute_error: 0.0161 - val_loss: 0.0068 - val_mean_absolute_error: 0.0683
# Epoch 7/80
# 30/30 [==============================] - 1s 27ms/step - loss: 4.6772e-04 - mean_absolute_error: 0.0154 - val_loss: 0.0044 - val_mean_absolute_error: 0.0532
# Epoch 8/80
# 30/30 [==============================] - 1s 25ms/step - loss: 4.3196e-04 - mean_absolute_error: 0.0148 - val_loss: 0.0054 - val_mean_absolute_error: 0.0605
# Epoch 9/80
# 30/30 [==============================] - 1s 26ms/step - loss: 4.2586e-04 - mean_absolute_error: 0.0148 - val_loss: 0.0049 - val_mean_absolute_error: 0.0565
# Epoch 10/80
# 30/30 [==============================] - 1s 25ms/step - loss: 4.1212e-04 - mean_absolute_error: 0.0147 - val_loss: 0.0071 - val_mean_absolute_error: 0.0707
# Epoch 11/80
# 30/30 [==============================] - 1s 26ms/step - loss: 3.9944e-04 - mean_absolute_error: 0.0143 - val_loss: 0.0044 - val_mean_absolute_error: 0.0518
# Epoch 12/80
# 30/30 [==============================] - 1s 26ms/step - loss: 3.9680e-04 - mean_absolute_error: 0.0146 - val_loss: 0.0050 - val_mean_absolute_error: 0.0561
# Epoch 13/80
# 30/30 [==============================] - 1s 26ms/step - loss: 3.6419e-04 - mean_absolute_error: 0.0137 - val_loss: 0.0107 - val_mean_absolute_error: 0.0876
# Epoch 14/80
# 30/30 [==============================] - 1s 26ms/step - loss: 3.3709e-04 - mean_absolute_error: 0.0136 - val_loss: 0.0079 - val_mean_absolute_error: 0.0724
# Epoch 15/80
# 30/30 [==============================] - 1s 27ms/step - loss: 3.2556e-04 - mean_absolute_error: 0.0134 - val_loss: 0.0083 - val_mean_absolute_error: 0.0750
# Epoch 16/80
# 30/30 [==============================] - 1s 27ms/step - loss: 3.2845e-04 - mean_absolute_error: 0.0134 - val_loss: 0.0077 - val_mean_absolute_error: 0.0709
# Epoch 17/80
# 30/30 [==============================] - 1s 26ms/step - loss: 3.3851e-04 - mean_absolute_error: 0.0134 - val_loss: 0.0100 - val_mean_absolute_error: 0.0839
# Epoch 18/80
# 30/30 [==============================] - 1s 26ms/step - loss: 3.6799e-04 - mean_absolute_error: 0.0141 - val_loss: 0.0111 - val_mean_absolute_error: 0.0898
# Epoch 19/80
# 30/30 [==============================] - 1s 26ms/step - loss: 3.2425e-04 - mean_absolute_error: 0.0133 - val_loss: 0.0093 - val_mean_absolute_error: 0.0795
# Epoch 20/80
# 30/30 [==============================] - 1s 27ms/step - loss: 3.0194e-04 - mean_absolute_error: 0.0128 - val_loss: 0.0084 - val_mean_absolute_error: 0.0743
# Epoch 21/80
# 30/30 [==============================] - 1s 26ms/step - loss: 3.4490e-04 - mean_absolute_error: 0.0138 - val_loss: 0.0069 - val_mean_absolute_error: 0.0654
# Epoch 22/80
# 30/30 [==============================] - 1s 27ms/step - loss: 3.9783e-04 - mean_absolute_error: 0.0150 - val_loss: 0.0089 - val_mean_absolute_error: 0.0793
# Epoch 23/80
# 30/30 [==============================] - 1s 26ms/step - loss: 3.3253e-04 - mean_absolute_error: 0.0133 - val_loss: 0.0055 - val_mean_absolute_error: 0.0600
# Epoch 24/80
# 30/30 [==============================] - 1s 27ms/step - loss: 2.9094e-04 - mean_absolute_error: 0.0126 - val_loss: 0.0067 - val_mean_absolute_error: 0.0657
# Epoch 25/80
# 30/30 [==============================] - 1s 29ms/step - loss: 3.0532e-04 - mean_absolute_error: 0.0128 - val_loss: 0.0081 - val_mean_absolute_error: 0.0731
# Epoch 26/80
# 30/30 [==============================] - 1s 26ms/step - loss: 2.8686e-04 - mean_absolute_error: 0.0124 - val_loss: 0.0067 - val_mean_absolute_error: 0.0656
# Epoch 27/80
# 30/30 [==============================] - 1s 27ms/step - loss: 2.7435e-04 - mean_absolute_error: 0.0122 - val_loss: 0.0079 - val_mean_absolute_error: 0.0722
# Epoch 28/80
# 30/30 [==============================] - 1s 27ms/step - loss: 3.0279e-04 - mean_absolute_error: 0.0129 - val_loss: 0.0068 - val_mean_absolute_error: 0.0654
# Epoch 29/80
# 30/30 [==============================] - 1s 26ms/step - loss: 2.9189e-04 - mean_absolute_error: 0.0128 - val_loss: 0.0062 - val_mean_absolute_error: 0.0632
# Epoch 30/80
# 30/30 [==============================] - 1s 26ms/step - loss: 2.6391e-04 - mean_absolute_error: 0.0118 - val_loss: 0.0076 - val_mean_absolute_error: 0.0727
# Epoch 31/80
# 30/30 [==============================] - 1s 29ms/step - loss: 2.7580e-04 - mean_absolute_error: 0.0122 - val_loss: 0.0044 - val_mean_absolute_error: 0.0516
# Epoch 32/80
# 30/30 [==============================] - 1s 28ms/step - loss: 2.4932e-04 - mean_absolute_error: 0.0116 - val_loss: 0.0091 - val_mean_absolute_error: 0.0796
# Epoch 33/80
# 30/30 [==============================] - 1s 28ms/step - loss: 2.5150e-04 - mean_absolute_error: 0.0117 - val_loss: 0.0060 - val_mean_absolute_error: 0.0614
# Epoch 34/80
# 30/30 [==============================] - 1s 26ms/step - loss: 2.6090e-04 - mean_absolute_error: 0.0119 - val_loss: 0.0050 - val_mean_absolute_error: 0.0558
# Epoch 35/80
# 30/30 [==============================] - 1s 26ms/step - loss: 2.5380e-04 - mean_absolute_error: 0.0117 - val_loss: 0.0066 - val_mean_absolute_error: 0.0678
# Epoch 36/80
# 30/30 [==============================] - 1s 26ms/step - loss: 3.0396e-04 - mean_absolute_error: 0.0131 - val_loss: 0.0037 - val_mean_absolute_error: 0.0468
# Epoch 37/80
# 30/30 [==============================] - 1s 27ms/step - loss: 2.4102e-04 - mean_absolute_error: 0.0114 - val_loss: 0.0050 - val_mean_absolute_error: 0.0561
# Epoch 38/80
# 30/30 [==============================] - 1s 26ms/step - loss: 2.9642e-04 - mean_absolute_error: 0.0129 - val_loss: 0.0027 - val_mean_absolute_error: 0.0391
# Epoch 39/80
# 30/30 [==============================] - 1s 25ms/step - loss: 2.5563e-04 - mean_absolute_error: 0.0119 - val_loss: 0.0031 - val_mean_absolute_error: 0.0428
# Epoch 40/80
# 30/30 [==============================] - 1s 28ms/step - loss: 2.3179e-04 - mean_absolute_error: 0.0112 - val_loss: 0.0044 - val_mean_absolute_error: 0.0524
# Epoch 41/80
# 30/30 [==============================] - 1s 26ms/step - loss: 2.3172e-04 - mean_absolute_error: 0.0112 - val_loss: 0.0078 - val_mean_absolute_error: 0.0723
# Epoch 42/80
# 30/30 [==============================] - 1s 27ms/step - loss: 2.2273e-04 - mean_absolute_error: 0.0111 - val_loss: 0.0028 - val_mean_absolute_error: 0.0397
# Epoch 43/80
# 30/30 [==============================] - 1s 27ms/step - loss: 2.3180e-04 - mean_absolute_error: 0.0113 - val_loss: 0.0048 - val_mean_absolute_error: 0.0547
# Epoch 44/80
# 30/30 [==============================] - 1s 27ms/step - loss: 2.2235e-04 - mean_absolute_error: 0.0109 - val_loss: 0.0048 - val_mean_absolute_error: 0.0546
# Epoch 45/80
# 30/30 [==============================] - 1s 26ms/step - loss: 2.2735e-04 - mean_absolute_error: 0.0110 - val_loss: 0.0050 - val_mean_absolute_error: 0.0558
# Epoch 46/80
# 30/30 [==============================] - 1s 25ms/step - loss: 2.1835e-04 - mean_absolute_error: 0.0108 - val_loss: 0.0074 - val_mean_absolute_error: 0.0713
# Epoch 47/80
# 30/30 [==============================] - 1s 27ms/step - loss: 2.0840e-04 - mean_absolute_error: 0.0105 - val_loss: 0.0056 - val_mean_absolute_error: 0.0607
# Epoch 48/80
# 30/30 [==============================] - 1s 26ms/step - loss: 2.0849e-04 - mean_absolute_error: 0.0106 - val_loss: 0.0048 - val_mean_absolute_error: 0.0559
# Epoch 49/80
# 30/30 [==============================] - 1s 26ms/step - loss: 1.9636e-04 - mean_absolute_error: 0.0102 - val_loss: 0.0030 - val_mean_absolute_error: 0.0431
# Epoch 50/80
# 30/30 [==============================] - 1s 30ms/step - loss: 2.0713e-04 - mean_absolute_error: 0.0105 - val_loss: 0.0061 - val_mean_absolute_error: 0.0639
# Epoch 51/80
# 30/30 [==============================] - 1s 26ms/step - loss: 1.9950e-04 - mean_absolute_error: 0.0104 - val_loss: 0.0032 - val_mean_absolute_error: 0.0431
# Epoch 52/80
# 30/30 [==============================] - 1s 26ms/step - loss: 2.0500e-04 - mean_absolute_error: 0.0105 - val_loss: 0.0034 - val_mean_absolute_error: 0.0433
# Epoch 53/80
# 30/30 [==============================] - 1s 26ms/step - loss: 2.1740e-04 - mean_absolute_error: 0.0109 - val_loss: 0.0037 - val_mean_absolute_error: 0.0457
# Epoch 54/80
# 30/30 [==============================] - 1s 26ms/step - loss: 1.9987e-04 - mean_absolute_error: 0.0103 - val_loss: 0.0071 - val_mean_absolute_error: 0.0706
# Epoch 55/80
# 30/30 [==============================] - 1s 27ms/step - loss: 1.9981e-04 - mean_absolute_error: 0.0102 - val_loss: 0.0047 - val_mean_absolute_error: 0.0535
# Epoch 56/80
# 30/30 [==============================] - 1s 25ms/step - loss: 2.0464e-04 - mean_absolute_error: 0.0103 - val_loss: 0.0065 - val_mean_absolute_error: 0.0646
# Epoch 57/80
# 30/30 [==============================] - 1s 26ms/step - loss: 1.8959e-04 - mean_absolute_error: 0.0100 - val_loss: 0.0061 - val_mean_absolute_error: 0.0631
# Epoch 58/80
# 30/30 [==============================] - 1s 25ms/step - loss: 1.8995e-04 - mean_absolute_error: 0.0100 - val_loss: 0.0064 - val_mean_absolute_error: 0.0662
# Epoch 59/80
# 30/30 [==============================] - 1s 26ms/step - loss: 1.8861e-04 - mean_absolute_error: 0.0101 - val_loss: 0.0032 - val_mean_absolute_error: 0.0430
# Epoch 60/80
# 30/30 [==============================] - 1s 26ms/step - loss: 1.8128e-04 - mean_absolute_error: 0.0098 - val_loss: 0.0039 - val_mean_absolute_error: 0.0478
# Epoch 61/80
# 30/30 [==============================] - 1s 26ms/step - loss: 1.7540e-04 - mean_absolute_error: 0.0097 - val_loss: 0.0044 - val_mean_absolute_error: 0.0507
# Epoch 62/80
# 30/30 [==============================] - 1s 25ms/step - loss: 1.7280e-04 - mean_absolute_error: 0.0094 - val_loss: 0.0072 - val_mean_absolute_error: 0.0689
# Epoch 63/80
# 30/30 [==============================] - 1s 26ms/step - loss: 1.8539e-04 - mean_absolute_error: 0.0099 - val_loss: 0.0042 - val_mean_absolute_error: 0.0502
# Epoch 64/80
# 30/30 [==============================] - 1s 27ms/step - loss: 1.6993e-04 - mean_absolute_error: 0.0096 - val_loss: 0.0037 - val_mean_absolute_error: 0.0475
# Epoch 65/80
# 30/30 [==============================] - 1s 26ms/step - loss: 1.7267e-04 - mean_absolute_error: 0.0095 - val_loss: 0.0049 - val_mean_absolute_error: 0.0562
# Epoch 66/80
# 30/30 [==============================] - 1s 27ms/step - loss: 1.7188e-04 - mean_absolute_error: 0.0095 - val_loss: 0.0052 - val_mean_absolute_error: 0.0585
# Epoch 67/80
# 30/30 [==============================] - 1s 25ms/step - loss: 1.7418e-04 - mean_absolute_error: 0.0096 - val_loss: 0.0059 - val_mean_absolute_error: 0.0626
# Epoch 68/80
# 30/30 [==============================] - 1s 26ms/step - loss: 1.5469e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0020 - val_mean_absolute_error: 0.0323
# Epoch 69/80
# 30/30 [==============================] - 1s 27ms/step - loss: 1.8076e-04 - mean_absolute_error: 0.0098 - val_loss: 0.0031 - val_mean_absolute_error: 0.0417
# Epoch 70/80
# 30/30 [==============================] - 1s 26ms/step - loss: 1.6202e-04 - mean_absolute_error: 0.0092 - val_loss: 0.0043 - val_mean_absolute_error: 0.0527
# Epoch 71/80
# 30/30 [==============================] - 1s 26ms/step - loss: 1.7930e-04 - mean_absolute_error: 0.0097 - val_loss: 0.0061 - val_mean_absolute_error: 0.0638
# Epoch 72/80
# 30/30 [==============================] - 1s 26ms/step - loss: 1.5105e-04 - mean_absolute_error: 0.0090 - val_loss: 0.0054 - val_mean_absolute_error: 0.0601
# Epoch 73/80
# 30/30 [==============================] - 1s 26ms/step - loss: 1.6518e-04 - mean_absolute_error: 0.0093 - val_loss: 0.0046 - val_mean_absolute_error: 0.0553
# Epoch 74/80
# 30/30 [==============================] - 1s 26ms/step - loss: 1.5281e-04 - mean_absolute_error: 0.0089 - val_loss: 0.0036 - val_mean_absolute_error: 0.0463
# Epoch 75/80
# 30/30 [==============================] - 1s 26ms/step - loss: 1.6532e-04 - mean_absolute_error: 0.0094 - val_loss: 0.0059 - val_mean_absolute_error: 0.0645
# Epoch 76/80
# 30/30 [==============================] - 1s 26ms/step - loss: 1.4924e-04 - mean_absolute_error: 0.0090 - val_loss: 0.0030 - val_mean_absolute_error: 0.0422
# Epoch 77/80
# 30/30 [==============================] - 1s 26ms/step - loss: 1.4912e-04 - mean_absolute_error: 0.0088 - val_loss: 0.0040 - val_mean_absolute_error: 0.0498
# Epoch 78/80
# 30/30 [==============================] - 1s 26ms/step - loss: 1.5289e-04 - mean_absolute_error: 0.0089 - val_loss: 0.0029 - val_mean_absolute_error: 0.0408
# Epoch 79/80
# 30/30 [==============================] - 1s 26ms/step - loss: 1.5382e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0035 - val_mean_absolute_error: 0.0474
# Epoch 80/80
# 30/30 [==============================] - 1s 27ms/step - loss: 1.5557e-04 - mean_absolute_error: 0.0089 - val_loss: 0.0025 - val_mean_absolute_error: 0.0388

# %%
test_predicted = model.predict(test_seq)
test_predicted[:5]
# Out:
# 7/7 [==============================] - 1s 8ms/step
# array([[0.4798638 , 0.4861335 ],
#        [0.48688778, 0.49311814],
#        [0.49213102, 0.4984121 ],
#        [0.5045405 , 0.5112682 ],
#        [0.51490664, 0.52179945]], dtype=float32)

# %%
test_inverse_predicted = MMS.inverse_transform(test_predicted) # Inversing scaling on predicted data
test_inverse_predicted[:5]
# Out:
# array([[1560.629 , 1569.2306],
#        [1573.651 , 1582.1755],
#        [1583.3715, 1591.987 ],
#        [1606.3777, 1615.8138],
#        [1625.5957, 1635.3318]], dtype=float32)

# %%
# Merging actual and predicted data for better visualization

gs_slic_data = pd.concat([google_stock_data.iloc[-202:].copy(),pd.DataFrame(test_inverse_predicted,columns=['open_predicted','close_predicted'],index=google_stock_data.iloc[-202:].index)], axis=1)

# %%
gs_slic_data[['open','close']] = MMS.inverse_transform(gs_slic_data[['open','close']]) # Inverse scaling

# %%
gs_slic_data.head()
# Out:
#                open    close  open_predicted  close_predicted
# date
# 2020-08-24  1593.98  1588.20     1560.629028      1569.230591
# 2020-08-25  1582.07  1608.22     1573.651001      1582.175537
# 2020-08-26  1608.00  1652.38     1583.371460      1591.987061
# 2020-08-27  1653.68  1634.33     1606.377686      1615.813843
# 2020-08-28  1633.49  1644.41     1625.595703      1635.331787

# %%
gs_slic_data[['open','open_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for open price',size=15)
plt.show()

# %%
gs_slic_data[['close','close_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for close price',size=15)
plt.show()

# %%
#predicting upcoming '10' days

# %%
# Creating a dataframe and adding 10 days to existing index 

gs_slic_data = gs_slic_data.append(pd.DataFrame(columns=gs_slic_data.columns,index=pd.date_range(start=gs_slic_data.index[-1], periods=11, freq='D', closed='right')))

# %%
gs_slic_data['2021-06-09	':'2021-06-16']
# Out:
#                open    close  open_predicted  close_predicted
# 2021-06-09  2499.50  2491.40     2271.770996      2357.797363
# 2021-06-10  2494.01  2521.60     2284.506348      2374.234619
# 2021-06-11  2524.92  2513.93     2292.611816      2385.497559
# 2021-06-12      NaN      NaN             NaN              NaN
# 2021-06-13      NaN      NaN             NaN              NaN
# 2021-06-14      NaN      NaN             NaN              NaN
# 2021-06-15      NaN      NaN             NaN              NaN
# 2021-06-16      NaN      NaN             NaN              NaN

# %%
upcoming_prediction = pd.DataFrame(columns=['open','close'],index=gs_slic_data.index)
upcoming_prediction.index=pd.to_datetime(upcoming_prediction.index)

# %%
curr_seq = test_seq[-1:]

for i in range(-10,0):
  up_pred = model.predict(curr_seq)
  upcoming_prediction.iloc[i] = up_pred
  curr_seq = np.append(curr_seq[0][1:],up_pred,axis=0)
  curr_seq = curr_seq.reshape(test_seq[-1:].shape)
# Out:
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 42ms/step

# %%
upcoming_prediction[['open','close']] = MMS.inverse_transform(upcoming_prediction[['open','close']])

# %%
fg,ax=plt.subplots(figsize=(10,5))
ax.plot(gs_slic_data.loc['2021-04-01':,'open'],label='Current Open Price')
ax.plot(upcoming_prediction.loc['2021-04-01':,'open'],label='Upcoming Open Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
ax.set_xlabel('Date',size=15)
ax.set_ylabel('Stock Price',size=15)
ax.set_title('Upcoming Open price prediction',size=15)
ax.legend()
fg.show()
# Out:
# C:\Users\NAZIRH~1\AppData\Local\Temp/ipykernel_2928/4155468105.py:9: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fg.show()

# %%
fg,ax=plt.subplots(figsize=(10,5))
ax.plot(gs_slic_data.loc['2021-04-01':,'close'],label='Current close Price')
ax.plot(upcoming_prediction.loc['2021-04-01':,'close'],label='Upcoming close Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
ax.set_xlabel('Date',size=15)
ax.set_ylabel('Stock Price',size=15)
ax.set_title('Upcoming close price prediction',size=15)
ax.legend()
fg.show()
# Out:
# C:\Users\NAZIRH~1\AppData\Local\Temp/ipykernel_2928/548185773.py:9: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fg.show()
